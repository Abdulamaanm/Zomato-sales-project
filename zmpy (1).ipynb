# %% [markdown]
# # ZOMATO DATA ANALYSIS PROJECT

# %%
import numpy as np
import seaborn as sns
import os
os.chdir("D:\data science default")
pd.set_option('display.max_row' , None)

# %% [markdown]
# # Create dataframe

# %%
zdata = pd.read_csv("Zomato_data.csv")
zdata
# Out:
#                                                 name online_order book_table  \
# 0                                              Jalsa          Yes        Yes
# 1                                     Spice Elephant          Yes         No
# 2                                    San Churro Cafe          Yes         No
# 3                              Addhuri Udupi Bhojana           No         No
# 4                                      Grand Village           No         No
# 5                                    Timepass Dinner          Yes         No
# 6    Rosewood International Hotel - Bar & Restaurant           No         No
# 7                                             Onesta          Yes        Yes
# 8                                     Penthouse Cafe          Yes         No
# 9                                          Smacznego          Yes         No
# 10                                      Village Café          Yes         No
# ...

# %%
# checking the null in the data

# %%
zdata.isnull().sum()
# Out:
# name                           0
# online_order                   0
# book_table                     0
# rate                           0
# votes                          0
# approx_cost(for two people)    0
# listed_in(type)                0
# dtype: int64

# %%
# checking the column information

# %%
for i in zdata.columns:
    print(i)
# Out:
# name
# online_order
# book_table
# rate
# votes
# approx_cost(for two people)
# listed_in(type)

# %% [markdown]
# # convert  the data type of column  rate

# %%
import pandas as pd

# Load the data
zdata = pd.read_csv("Zomato_data.csv")

# Define the rate handling function
def handlerate(value):
    try:
        value = str(value).split("/")[0].strip()  # Split by '/' and take the first part
        return float(value)  # Convert to float
    except ValueError:
        return None  

# Apply the function to the 'rate' column
zdata["rate"] = zdata["rate"].apply(handlerate)

# Optionally, convert to integer if you want to remove fractional values
zdata["rate"] = zdata["rate"].fillna(0).astype(int)  # Replace NaN with 0 or choose another strategy

zdata
# Out:
#                                                 name online_order book_table  \
# 0                                              Jalsa          Yes        Yes
# 1                                     Spice Elephant          Yes         No
# 2                                    San Churro Cafe          Yes         No
# 3                              Addhuri Udupi Bhojana           No         No
# 4                                      Grand Village           No         No
# 5                                    Timepass Dinner          Yes         No
# 6    Rosewood International Hotel - Bar & Restaurant           No         No
# 7                                             Onesta          Yes        Yes
# 8                                     Penthouse Cafe          Yes         No
# 9                                          Smacznego          Yes         No
# 10                                      Village Café          Yes         No
# ...

# %% [markdown]
# # types of resturant

# %%
zdata.head()
# Out:
#                     name online_order book_table  rate  votes  \
# 0                  Jalsa          Yes        Yes     4    775
# 1         Spice Elephant          Yes         No     4    787
# 2        San Churro Cafe          Yes         No     3    918
# 3  Addhuri Udupi Bhojana           No         No     3     88
# 4          Grand Village           No         No     3    166
#
#    approx_cost(for two people) listed_in(type)
# 0                          800          Buffet
# 1                          800          Buffet
# 2                          800          Buffet
# 3                          300          Buffet
# 4                          600          Buffet

# %%
sns.countplot(x=zdata["listed_in(type)"])
plt.xlabel("tyes of resturant", color= "green")
plt.show()

# %% [markdown]
# # conclusion: is that majority of the resturant falls in the dinning category

# %%
groupdata= zdata.groupby("listed_in(type)")["votes"].sum()
groupdata
result= pd.DataFrame(groupdata)
result
# Out:
#                  votes
# listed_in(type)
# Buffet            3028
# Cafes             6434
# Dining           20363
# other             9367

# %%
plt.plot(groupdata.index, groupdata.values, color="red", marker="d", linestyle='--')
plt.xlabel("tyes of resturant", color= "green", fontweight='bold')
plt.ylabel("votes", color="blue", fontweight='bold')
# Out:
# Text(0, 0.5, 'votes')

# %% [markdown]
# # conclusion show that  buffet get the lowest votes and dining get the highest votes

# %%
zdata.head()

plt.hist(zdata["rate"], bins=3, histtype="step", color="green")
plt.title("rating distribution")
plt.xlabel("rate", fontweight= "bold", color="blue")
# Out:
# Text(0.5, 0, 'rate')

# %% [markdown]
# # most of  resturant rating falls between 2.75 to 3.5

# %%
# average spending  by couple

# %%
sns.countplot(x=zdata["approx_cost(for two people)"])
# Out:
# <Axes: xlabel='approx_cost(for two people)', ylabel='count'>

# %%
# most of the people preferr resturants with an approx cost of 300 ruppes on online food by this we can so them good offers

# %%
# which mode get the more rating in offline  and online us of box plot

# %%
sns.boxplot(x= zdata["online_order"], y=zdata["rate"])
plt.xlabel("online_order",fontweight='bold', color="orange")
plt.ylabel("rate",fontweight='bold', color="red")
plt.show()

# %% [markdown]
# # so here we can see that online order get more rating the offline line

# %%
# type of resturant recived  more offline orders

# %%
pivot= zdata.pivot_table( index="listed_in(type)", columns="online_order", aggfunc= "size")

sns.heatmap( pivot, annot=True, fmt="d", cmap= "YlGnBu")
plt.xlabel("online_order",fontweight="bold", color="red")
plt.ylabel("typeof cafe",fontweight="bold", color="red")
plt.show()

# %% [markdown]
# # here we see that  cafes get more online order here as compare to offline
